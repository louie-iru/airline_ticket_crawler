# %% [markdown]
# # Library

# %%
from urllib.request import urlopen
from pandas import json_normalize
from tqdm import tqdm, trange
from datetime import datetime, timedelta
from sqlalchemy import types, create_engine
from tqdm import tqdm 

import pandas as pd
import json
import time
# import cx_Oracle
import os

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Functions

# %%
## Get JSON from API url

def get_json(dep_city, arr_city, date, airline):
    url = (
        'https://domair.interpark.com/api/booking/airJourney.do?format=json&dep=' 
        + dep_city
        + '&arr=' 
        + arr_city
        + '&depDate=' 
        + date 
        +'&adt=1&chd=0&inf=0&tripDivi=0&airlineCode=' 
        + airline 
        + '&siteCode='
    )
    
    try:
        json_data = json.load(urlopen(url))

        #Error check
        if json_data == None:
            print("[F1]", dep_city, arr_city, date, airline, " - Null page")

        elif json_data['replyAvailFare'] == None :
            print("[F1]", dep_city, arr_city, date, airline, " - Available ticket is none")

        elif json_data['replyHeader']['errorCode'] != '0': 
            print("[F1]", dep_city, arr_city, date, airline, "Error Code: ", json_data['replyHeader']['errorCode'], " - Try again after a min ...")
            time.sleep(60)
            get_json(dep_city, arr_city, date, airline) # Recursion
            
        else:
            print(dep_city, arr_city, date, airline,"is okay !")
            return json_data
    
    except Exception as ex:

        print("[F1] Error code: ", ex)
        print("Sleep a min ... ")

        time.sleep(60)

        print("Retry !")
        get_json(dep_city, arr_city, date, airline) # Recursion

# %%
## JSON parsing and get details

def get_tickets(json_data):
    df = pd.DataFrame(
        columns = ['depart_date', 'depart_time', 'airline', 'flight_no', 'depart', 'arrive', 'class_code', 'class_desc', 'avail_seat', 'fare_origin', 'fare']
    )

    try:
        for i in range(len(json_data['replyAvailFare']['availFareSet'])):
            for j in range(len(json_data['replyAvailFare']['availFareSet'][i]['segFare']['classDetail'])):
                depart_date = json_data['replyAvailFare']['availFareSet'][i]['segFare']['depDate']
                depart_time = json_data['replyAvailFare']['availFareSet'][i]['segFare']['depTime']
                airline_code = json_data['replyAvailFare']['availFareSet'][i]['segFare']['carCode']
                flight_no = json_data['replyAvailFare']['availFareSet'][i]['segFare']['mainFlt']
                depart_code = json_data['replyAvailFare']['availFareSet'][i]['segFare']['depCity']
                arrive_code = json_data['replyAvailFare']['availFareSet'][i]['segFare']['arrCity']
                class_code = json_data['replyAvailFare']['availFareSet'][i]['segFare']['classDetail'][j]['classCode']
                class_desc = json_data['replyAvailFare']['availFareSet'][i]['segFare']['classDetail'][j]['classDesc']
                avail_seat = json_data['replyAvailFare']['availFareSet'][i]['segFare']['classDetail'][j]['noOfAvailSeat']
                fare = json_data['replyAvailFare']['availFareSet'][i]['segFare']['classDetail'][j]['fare']
                fare_origin = json_data['replyAvailFare']['availFareSet'][i]['segFare']['classDetail'][j]['fareOrigin']

                data_list = [depart_date, depart_time, airline_code, flight_no, depart_code, arrive_code, class_code, class_desc, avail_seat, fare_origin, fare]
                data_series = pd.Series(data_list, index = df.columns)
                df = df.append(data_series, ignore_index = True)
                # df = pd.concat([df, data_series], ignore_index = True)

    except Exception as e:
        print("[F2] Error code: " + str(e))
            
    return df

# %%
## Data processing

def data_processing(ticket_df):
    
    # Search date & time adding
    ticket_df['search_date'] = datetime.today().strftime('%Y%m%d')
    ticket_df['search_time'] = datetime.today().strftime('%H%M')

    # Data types changing
    ticket_df = ticket_df.astype(
        {
            'depart_date': 'datetime64'
            , 'depart_time': 'string'
            , 'airline': 'string'
            , 'flight_no': 'string'
            , 'depart': 'string'
            , 'arrive': 'string'
            , 'class_code': 'string'
            , 'class_desc': 'string'
            , 'avail_seat': 'int'
            , 'fare_origin': 'int'
            , 'fare': 'int'
            , 'search_date': 'datetime64'
            , 'search_time': 'string'
        }
    )
    
    return ticket_df

# %%
## Stack data into Oracle DB

def to_oracle(total_df):
    id = "sample"
    pw = "sample"
    address = "smaple"

    connect = create_engine(f"oracle+cx_oracle://{id}:{pw}@{address}")
    
    try:
        total_df.to_sql("Table name"
            , connect
            , if_exists = 'append'
            , index = False
            , dtype={
                'depart_date': types.Date()
                , 'depart_time': types.VARCHAR()
                , 'airline': types.VARCHAR()
                , 'flight_no': types.VARCHAR()
                , 'depart': types.VARCHAR()
                , 'arrive': types.VARCHAR()
                , 'class_code': types.VARCHAR()
                , 'class_desc': types.VARCHAR()
        #         , 'avail_seat': 'int'
        #         , 'fare_origin': 'int'
                , 'fare': types.VARCHAR()
                , 'search_date': types.Date()
                , 'search_time': types.VARCHAR()
                 }
            )

    except Exception as ex:
        print("[F4] Error code: ", ex)

# %%
## Slack notification

def send_slack_message(channel_name, title, file_name, start_time):
    slack_token = "****"
    client = WebClient(token=slack_token)

    content = """
        # %s , %s
        """ % (title, start_time)
    file_exist = False
    file_extension = ''

    if os.path.isfile(file_name):
        path, ext= os.path.splitext(file_name)
        file_extension = ext.strip('.')
        print("ext : " +file_extension)
        file_exist = True

    else:
        file_exist = False

    try:
        response = client.chat_postMessage(channel = channel_name, text = content)
        print(response['ok'])
        
        if file_exist:
            response_file_1 = client.files_upload(channels = channel_name
                                                , file = file_name
                                                , filename = file_name
                                                , filetype = file_extension
                                                )
            print(response_file_1['ok'])
        else:
            response_file_error = client.chat_postMessage(channel = channel_name, text = "No files to upload.")
            print(response_file_error['ok'])


    except SlackApiError as e:
        print('Error: {}'.format(e.response['error']))

    except Exception as e:
        print('Error : ' + str(e))

# %%
## Stack into Google Cloud Storage

def upload_to_bucket(file_name):
    # os.getcwd() +  
    os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "JSON key"
    client = storage.Client()
    bucket = client.get_bucket("storage name")
    blob = bucket.blob("storage name" + file_name)
    blob.upload_from_filename(file_name)

# %%
## Create BigQuery DB

def insert_to_bigquery_table(dataframe):
    try:
        os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = os.getcwd() +  "JSON key"

        # Construct a BigQuery client object.
        client = bigquery.Client()

        table_id = "****"
        table = client.get_table(table_id)  # Make an API request.

        job_config = bigquery.LoadJobConfig(
            schema=[
                ]
        )
        
        job = client.load_table_from_dataframe(
            dataframe, table_id, job_config=job_config
        )  # Make an API request.

        job.result()  
        # Wait for the job to complete.

        table = client.get_table(table_id)  # Make an API request.
        print(
            "Loaded {} rows and {} columns to {}".format(
                table.num_rows, len(table.schema), table_id
            )
        )

    except Exception as e:
        print("Error : " + str(e))

# %% [markdown]
# # Main

# %%
start_time = datetime.now()
print("Start: ", start_time.strftime('%Y-%m-%d %H:%M'))

# send_slack_message("crawling_logs", "airline_ticket (시작)", "", start_time)

final_df = pd.DataFrame()
line_list = ['GMP', 'CJU'], ['PUS', 'CJU'], ['CJJ', 'CJU'], ['TAE', 'CJU'], ['KWJ', 'CJU'], ['CJU', 'GMP'], ['CJU', 'PUS'], ['CJU', 'CJJ'], ['CJU', 'TAE'], ['CJU', 'KWJ']
airline_list = ['KE', 'OZ', '7C', 'LJ', 'TW', 'BX'] # Airlines code, 'RS' is unstable

for line in tqdm(line_list):
    
    for date in range(1, 61):
        
        date = datetime.today() + timedelta(days = date)
        date = date.strftime('%Y%m%d')
        # print(date)
        
        for airline in airline_list:
            
            json_data = get_json(line[0], line[1], date, airline)
            
            if json_data == None:
                
                continue

            else:

                ticket_df = get_tickets(json_data)

                total_df = data_processing(ticket_df)
                
                final_df = final_df.append(total_df, ignore_index = True)
                # final_df = pd.concat([final_df, total_df], ignore_index = True)
                # to_oracle(total_df)

                # # to parquet
                # end_time = datetime.now()
                # e_time_re = end_time.strftime('%Y%m%d_%H%M')
                # filename = "airline_ticket_" + e_time_re + ".parquet"
                # total_df.to_parquet(filename, engine="pyarrow", compression="gzip")
                # upload_to_bucket(filename)
                # insert_to_bigquery_table(total_df)


end_time = datetime.now()
running_time = end_time - start_time
print("End: ", end_time.strftime('%Y-%m-%d %H:%M'))
print("Running time: ", running_time)

# send_slack_message("crawling_logs", "airline_ticket (종료)", "airline.log", running_time)
# Out:
# Start:  2023-01-02 10:10
#   0%|          | 0/10 [00:00<?, ?it/s]
# GMP CJU 20230103 KE is okay !
# GMP CJU 20230103 OZ is okay !
# GMP CJU 20230103 7C is okay !
# GMP CJU 20230103 LJ is okay !
# GMP CJU 20230103 TW is okay !
# GMP CJU 20230103 BX is okay !
# GMP CJU 20230104 KE is okay !
# GMP CJU 20230104 OZ is okay !
# GMP CJU 20230104 7C is okay !
# GMP CJU 20230104 LJ is okay !
# GMP CJU 20230104 TW is okay !
# GMP CJU 20230104 BX is okay !
# GMP CJU 20230105 KE is okay !
# GMP CJU 20230105 OZ is okay !
# GMP CJU 20230105 7C is okay !
# GMP CJU 20230105 LJ is okay !
# GMP CJU 20230105 TW is okay !
# GMP CJU 20230105 BX is okay !
# GMP CJU 20230106 KE is okay !
# GMP CJU 20230106 OZ is okay !
# GMP CJU 20230106 7C is okay !
# GMP CJU 20230106 LJ is okay !
# GMP CJU 20230106 TW is okay !
# GMP CJU 20230106 BX is okay !
# GMP CJU 20230107 KE is okay !
# GMP CJU 20230107 OZ is okay !
# GMP CJU 20230107 7C is okay !
# GMP CJU 20230107 LJ is okay !
# GMP CJU 20230107 TW is okay !
# GMP CJU 20230107 BX is okay !
# GMP CJU 20230108 KE is okay !
# GMP CJU 20230108 OZ is okay !
# GMP CJU 20230108 7C is okay !
# GMP CJU 20230108 LJ is okay !
# GMP CJU 20230108 TW is okay !
# GMP CJU 20230108 BX is okay !
# GMP CJU 20230109 KE is okay !
# GMP CJU 20230109 OZ is okay !
# GMP CJU 20230109 7C is okay !
# GMP CJU 20230109 LJ is okay !
# GMP CJU 20230109 TW is okay !
# GMP CJU 20230109 BX is okay !
# GMP CJU 20230110 KE is okay !
# GMP CJU 20230110 OZ is okay !
# GMP CJU 20230110 7C is okay !
# GMP CJU 20230110 LJ is okay !
# GMP CJU 20230110 TW is okay !
# GMP CJU 20230110 BX is okay !
# GMP CJU 20230111 KE is okay !
# GMP CJU 20230111 OZ is okay !
# GMP CJU 20230111 7C is okay !
# GMP CJU 20230111 LJ is okay !
# GMP CJU 20230111 TW is okay !
# GMP CJU 20230111 BX is okay !
# GMP CJU 20230112 KE is okay !
# GMP CJU 20230112 OZ is okay !
# GMP CJU 20230112 7C is okay !
# GMP CJU 20230112 LJ is okay !
# GMP CJU 20230112 TW is okay !
# GMP CJU 20230112 BX is okay !
# GMP CJU 20230113 KE is okay !
# GMP CJU 20230113 OZ is okay !
# GMP CJU 20230113 7C is okay !
# GMP CJU 20230113 LJ is okay !
# GMP CJU 20230113 TW is okay !
# GMP CJU 20230113 BX is okay !
# GMP CJU 20230114 KE is okay !
# GMP CJU 20230114 OZ is okay !
# GMP CJU 20230114 7C is okay !
# GMP CJU 20230114 LJ is okay !
# GMP CJU 20230114 TW is okay !
# GMP CJU 20230114 BX is okay !
# GMP CJU 20230115 KE is okay !
# GMP CJU 20230115 OZ is okay !
# GMP CJU 20230115 7C is okay !
# GMP CJU 20230115 LJ is okay !
# GMP CJU 20230115 TW is okay !
# GMP CJU 20230115 BX is okay !
# GMP CJU 20230116 KE is okay !
# GMP CJU 20230116 OZ is okay !
# GMP CJU 20230116 7C is okay !
# GMP CJU 20230116 LJ is okay !
# GMP CJU 20230116 TW is okay !
# GMP CJU 20230116 BX is okay !
# GMP CJU 20230117 KE is okay !
# GMP CJU 20230117 OZ is okay !
# GMP CJU 20230117 7C is okay !
# GMP CJU 20230117 LJ is okay !
# GMP CJU 20230117 TW is okay !
# GMP CJU 20230117 BX is okay !
# GMP CJU 20230118 KE is okay !
# GMP CJU 20230118 OZ is okay !
# GMP CJU 20230118 7C is okay !
# GMP CJU 20230118 LJ is okay !
# GMP CJU 20230118 TW is okay !
# GMP CJU 20230118 BX is okay !
# GMP CJU 20230119 KE is okay !
# GMP CJU 20230119 OZ is okay !
# GMP CJU 20230119 7C is okay !
# GMP CJU 20230119 LJ is okay !
# GMP CJU 20230119 TW is okay !
# GMP CJU 20230119 BX is okay !
# [F1] GMP CJU 20230120 KE  - Available ticket is none
# GMP CJU 20230120 OZ is okay !
# GMP CJU 20230120 7C is okay !
# GMP CJU 20230120 LJ is okay !
# GMP CJU 20230120 TW is okay !
# GMP CJU 20230120 BX is okay !
# [F1] GMP CJU 20230121 KE  - Available ticket is none
# [F1] GMP CJU 20230121 OZ  - Available ticket is none
# [F1] GMP CJU 20230121 7C  - Available ticket is none
# GMP CJU 20230121 LJ is okay !
# [F2] Error code: object of type 'NoneType' has no len()
# GMP CJU 20230121 TW is okay !
# [F2] Error code: object of type 'NoneType' has no len()
# GMP CJU 20230121 BX is okay !
# [F2] Error code: object of type 'NoneType' has no len()
# GMP CJU 20230122 KE is okay !
# GMP CJU 20230122 OZ is okay !
# GMP CJU 20230122 7C is okay !
# GMP CJU 20230122 LJ is okay !
# GMP CJU 20230122 TW is okay !
# GMP CJU 20230122 BX is okay !
# GMP CJU 20230123 KE is okay !
# GMP CJU 20230123 OZ is okay !
# GMP CJU 20230123 7C is okay !
# GMP CJU 20230123 LJ is okay !
# GMP CJU 20230123 TW is okay !
# GMP CJU 20230123 BX is okay !
# GMP CJU 20230124 KE is okay !
# GMP CJU 20230124 OZ is okay !
# GMP CJU 20230124 7C is okay !
# GMP CJU 20230124 LJ is okay !
# GMP CJU 20230124 TW is okay !
# GMP CJU 20230124 BX is okay !
# GMP CJU 20230125 KE is okay !
# GMP CJU 20230125 OZ is okay !
# GMP CJU 20230125 7C is okay !
# GMP CJU 20230125 LJ is okay !
# GMP CJU 20230125 TW is okay !
# GMP CJU 20230125 BX is okay !
# GMP CJU 20230126 KE is okay !
# GMP CJU 20230126 OZ is okay !
# GMP CJU 20230126 7C is okay !
# GMP CJU 20230126 LJ is okay !
# GMP CJU 20230126 TW is okay !
# GMP CJU 20230126 BX is okay !
# GMP CJU 20230127 KE is okay !
# GMP CJU 20230127 OZ is okay !
# GMP CJU 20230127 7C is okay !
# GMP CJU 20230127 LJ is okay !
# GMP CJU 20230127 TW is okay !
# GMP CJU 20230127 BX is okay !
# GMP CJU 20230128 KE is okay !
# GMP CJU 20230128 OZ is okay !
# GMP CJU 20230128 7C is okay !
# GMP CJU 20230128 LJ is okay !
# GMP CJU 20230128 TW is okay !
# GMP CJU 20230128 BX is okay !
# GMP CJU 20230129 KE is okay !
# GMP CJU 20230129 OZ is okay !
# GMP CJU 20230129 7C is okay !
# GMP CJU 20230129 LJ is okay !
# GMP CJU 20230129 TW is okay !
# GMP CJU 20230129 BX is okay !
# GMP CJU 20230130 KE is okay !
# GMP CJU 20230130 OZ is okay !
# GMP CJU 20230130 7C is okay !
# GMP CJU 20230130 LJ is okay !
# GMP CJU 20230130 TW is okay !
# GMP CJU 20230130 BX is okay !
# GMP CJU 20230131 KE is okay !
# GMP CJU 20230131 OZ is okay !
# GMP CJU 20230131 7C is okay !
# GMP CJU 20230131 LJ is okay !
# GMP CJU 20230131 TW is okay !
# GMP CJU 20230131 BX is okay !
# GMP CJU 20230201 KE is okay !
# GMP CJU 20230201 OZ is okay !
# GMP CJU 20230201 7C is okay !
# GMP CJU 20230201 LJ is okay !
# GMP CJU 20230201 TW is okay !
# GMP CJU 20230201 BX is okay !
# GMP CJU 20230202 KE is okay !
# GMP CJU 20230202 OZ is okay !
# GMP CJU 20230202 7C is okay !
# GMP CJU 20230202 LJ is okay !
# GMP CJU 20230202 TW is okay !
# GMP CJU 20230202 BX is okay !
# GMP CJU 20230203 KE is okay !
# GMP CJU 20230203 OZ is okay !
# GMP CJU 20230203 7C is okay !
# GMP CJU 20230203 LJ is okay !
# GMP CJU 20230203 TW is okay !
# GMP CJU 20230203 BX is okay !
# GMP CJU 20230204 KE is okay !
# GMP CJU 20230204 OZ is okay !
# GMP CJU 20230204 7C is okay !
# GMP CJU 20230204 LJ is okay !
# GMP CJU 20230204 TW is okay !
# GMP CJU 20230204 BX is okay !
# GMP CJU 20230205 KE is okay !
# GMP CJU 20230205 OZ is okay !
# GMP CJU 20230205 7C is okay !
# GMP CJU 20230205 LJ is okay !
# GMP CJU 20230205 TW is okay !
# GMP CJU 20230205 BX is okay !
# GMP CJU 20230206 KE is okay !
# GMP CJU 20230206 OZ is okay !
# GMP CJU 20230206 7C is okay !
# GMP CJU 20230206 LJ is okay !
# GMP CJU 20230206 TW is okay !
# GMP CJU 20230206 BX is okay !
# GMP CJU 20230207 KE is okay !
# GMP CJU 20230207 OZ is okay !
# GMP CJU 20230207 7C is okay !
# GMP CJU 20230207 LJ is okay !
# GMP CJU 20230207 TW is okay !
# GMP CJU 20230207 BX is okay !
# GMP CJU 20230208 KE is okay !
# GMP CJU 20230208 OZ is okay !
# GMP CJU 20230208 7C is okay !
# GMP CJU 20230208 LJ is okay !
# GMP CJU 20230208 TW is okay !
# GMP CJU 20230208 BX is okay !
# GMP CJU 20230209 KE is okay !
# GMP CJU 20230209 OZ is okay !
# GMP CJU 20230209 7C is okay !
# GMP CJU 20230209 LJ is okay !
# GMP CJU 20230209 TW is okay !
# GMP CJU 20230209 BX is okay !
# GMP CJU 20230210 KE is okay !
# GMP CJU 20230210 OZ is okay !
# GMP CJU 20230210 7C is okay !
# GMP CJU 20230210 LJ is okay !
# GMP CJU 20230210 TW is okay !
# GMP CJU 20230210 BX is okay !
# GMP CJU 20230211 KE is okay !
# GMP CJU 20230211 OZ is okay !
# GMP CJU 20230211 7C is okay !
# GMP CJU 20230211 LJ is okay !
# GMP CJU 20230211 TW is okay !
# GMP CJU 20230211 BX is okay !
# GMP CJU 20230212 KE is okay !
# GMP CJU 20230212 OZ is okay !
# GMP CJU 20230212 7C is okay !
# GMP CJU 20230212 LJ is okay !
# GMP CJU 20230212 TW is okay !
# GMP CJU 20230212 BX is okay !
# GMP CJU 20230213 KE is okay !
# GMP CJU 20230213 OZ is okay !
# GMP CJU 20230213 7C is okay !
# GMP CJU 20230213 LJ is okay !
# GMP CJU 20230213 TW is okay !
# GMP CJU 20230213 BX is okay !
# GMP CJU 20230214 KE is okay !
# GMP CJU 20230214 OZ is okay !
# GMP CJU 20230214 7C is okay !
# GMP CJU 20230214 LJ is okay !
# GMP CJU 20230214 TW is okay !
# GMP CJU 20230214 BX is okay !
# GMP CJU 20230215 KE is okay !
# GMP CJU 20230215 OZ is okay !
# GMP CJU 20230215 7C is okay !
# GMP CJU 20230215 LJ is okay !
# GMP CJU 20230215 TW is okay !
# GMP CJU 20230215 BX is okay !
# GMP CJU 20230216 KE is okay !
# GMP CJU 20230216 OZ is okay !
# GMP CJU 20230216 7C is okay !
# GMP CJU 20230216 LJ is okay !
# GMP CJU 20230216 TW is okay !
# GMP CJU 20230216 BX is okay !
# GMP CJU 20230217 KE is okay !
# GMP CJU 20230217 OZ is okay !
# GMP CJU 20230217 7C is okay !
# GMP CJU 20230217 LJ is okay !
# GMP CJU 20230217 TW is okay !
# GMP CJU 20230217 BX is okay !
# GMP CJU 20230218 KE is okay !
# GMP CJU 20230218 OZ is okay !
# GMP CJU 20230218 7C is okay !
# GMP CJU 20230218 LJ is okay !
# GMP CJU 20230218 TW is okay !
# GMP CJU 20230218 BX is okay !
# GMP CJU 20230219 KE is okay !
# GMP CJU 20230219 OZ is okay !
# GMP CJU 20230219 7C is okay !
# GMP CJU 20230219 LJ is okay !
# GMP CJU 20230219 TW is okay !
# GMP CJU 20230219 BX is okay !
# GMP CJU 20230220 KE is okay !
# GMP CJU 20230220 OZ is okay !
# GMP CJU 20230220 7C is okay !
# GMP CJU 20230220 LJ is okay !
# GMP CJU 20230220 TW is okay !
# GMP CJU 20230220 BX is okay !
# GMP CJU 20230221 KE is okay !
# GMP CJU 20230221 OZ is okay !
# GMP CJU 20230221 7C is okay !
# GMP CJU 20230221 LJ is okay !
# GMP CJU 20230221 TW is okay !
# GMP CJU 20230221 BX is okay !
# GMP CJU 20230222 KE is okay !
# GMP CJU 20230222 OZ is okay !
# GMP CJU 20230222 7C is okay !
# GMP CJU 20230222 LJ is okay !
# GMP CJU 20230222 TW is okay !
# GMP CJU 20230222 BX is okay !
# GMP CJU 20230223 KE is okay !
# GMP CJU 20230223 OZ is okay !
# GMP CJU 20230223 7C is okay !
# GMP CJU 20230223 LJ is okay !
# GMP CJU 20230223 TW is okay !
# GMP CJU 20230223 BX is okay !
# GMP CJU 20230224 KE is okay !
# GMP CJU 20230224 OZ is okay !
# GMP CJU 20230224 7C is okay !
# GMP CJU 20230224 LJ is okay !
# GMP CJU 20230224 TW is okay !
# GMP CJU 20230224 BX is okay !
# GMP CJU 20230225 KE is okay !
# GMP CJU 20230225 OZ is okay !
# GMP CJU 20230225 7C is okay !
# GMP CJU 20230225 LJ is okay !
# GMP CJU 20230225 TW is okay !
# GMP CJU 20230225 BX is okay !
# GMP CJU 20230226 KE is okay !
# GMP CJU 20230226 OZ is okay !
# GMP CJU 20230226 7C is okay !
# GMP CJU 20230226 LJ is okay !
# GMP CJU 20230226 TW is okay !
# GMP CJU 20230226 BX is okay !
# GMP CJU 20230227 KE is okay !
# GMP CJU 20230227 OZ is okay !
# GMP CJU 20230227 7C is okay !
# GMP CJU 20230227 LJ is okay !
# GMP CJU 20230227 TW is okay !
# GMP CJU 20230227 BX is okay !
# GMP CJU 20230228 KE is okay !
# GMP CJU 20230228 OZ is okay !
# GMP CJU 20230228 7C is okay !
# GMP CJU 20230228 LJ is okay !
# GMP CJU 20230228 TW is okay !
# GMP CJU 20230228 BX is okay !
# GMP CJU 20230301 KE is okay !
# GMP CJU 20230301 OZ is okay !
# GMP CJU 20230301 7C is okay !
# GMP CJU 20230301 LJ is okay !
# GMP CJU 20230301 TW is okay !
# GMP CJU 20230301 BX is okay !
# GMP CJU 20230302 KE is okay !
# GMP CJU 20230302 OZ is okay !
# GMP CJU 20230302 7C is okay !
# GMP CJU 20230302 LJ is okay !
# GMP CJU 20230302 TW is okay !
# GMP CJU 20230302 BX is okay !
# GMP CJU 20230303 KE is okay !
# GMP CJU 20230303 OZ is okay !
# GMP CJU 20230303 7C is okay !
# GMP CJU 20230303 LJ is okay !
# GMP CJU 20230303 TW is okay !
#  10%|█         | 1/10 [03:32<31:54, 212.71s/it]
# GMP CJU 20230303 BX is okay !
# PUS CJU 20230103 KE is okay !
# PUS CJU 20230103 OZ is okay !
# PUS CJU 20230103 7C is okay !
# PUS CJU 20230103 LJ is okay !
# [F1] PUS CJU 20230103 TW  - Available ticket is none
# PUS CJU 20230103 BX is okay !
# PUS CJU 20230104 KE is okay !
# PUS CJU 20230104 OZ is okay !
# PUS CJU 20230104 7C is okay !
# PUS CJU 20230104 LJ is okay !
# [F1] PUS CJU 20230104 TW  - Available ticket is none
# PUS CJU 20230104 BX is okay !
# PUS CJU 20230105 KE is okay !
# PUS CJU 20230105 OZ is okay !
# PUS CJU 20230105 7C is okay !
# PUS CJU 20230105 LJ is okay !
# [F1] PUS CJU 20230105 TW  - Available ticket is none
# PUS CJU 20230105 BX is okay !
# PUS CJU 20230106 KE is okay !
# [F1] PUS CJU 20230106 OZ  - Available ticket is none
# PUS CJU 20230106 7C is okay !
# PUS CJU 20230106 LJ is okay !
# [F1] PUS CJU 20230106 TW  - Available ticket is none
# PUS CJU 20230106 BX is okay !
# PUS CJU 20230107 KE is okay !
# PUS CJU 20230107 OZ is okay !
# PUS CJU 20230107 7C is okay !
# PUS CJU 20230107 LJ is okay !
# [F1] PUS CJU 20230107 TW  - Available ticket is none
# PUS CJU 20230107 BX is okay !
# PUS CJU 20230108 KE is okay !
# PUS CJU 20230108 OZ is okay !
# PUS CJU 20230108 7C is okay !
# PUS CJU 20230108 LJ is okay !
# [F1] PUS CJU 20230108 TW  - Available ticket is none
# PUS CJU 20230108 BX is okay !
# PUS CJU 20230109 KE is okay !
# PUS CJU 20230109 OZ is okay !
# PUS CJU 20230109 7C is okay !
# PUS CJU 20230109 LJ is okay !
# [F1] PUS CJU 20230109 TW  - Available ticket is none
# PUS CJU 20230109 BX is okay !
# PUS CJU 20230110 KE is okay !
# PUS CJU 20230110 OZ is okay !
# PUS CJU 20230110 7C is okay !
# PUS CJU 20230110 LJ is okay !
# [F1] PUS CJU 20230110 TW  - Available ticket is none
# PUS CJU 20230110 BX is okay !
# PUS CJU 20230111 KE is okay !
# PUS CJU 20230111 OZ is okay !
# PUS CJU 20230111 7C is okay !
# PUS CJU 20230111 LJ is okay !
# [F1] PUS CJU 20230111 TW  - Available ticket is none
# PUS CJU 20230111 BX is okay !
# PUS CJU 20230112 KE is okay !
# PUS CJU 20230112 OZ is okay !
# PUS CJU 20230112 7C is okay !
# PUS CJU 20230112 LJ is okay !
# [F1] PUS CJU 20230112 TW  - Available ticket is none
# PUS CJU 20230112 BX is okay !
# PUS CJU 20230113 KE is okay !
# [F1] PUS CJU 20230113 OZ  - Available ticket is none
# PUS CJU 20230113 7C is okay !
# PUS CJU 20230113 LJ is okay !
# [F1] PUS CJU 20230113 TW  - Available ticket is none
# PUS CJU 20230113 BX is okay !
# PUS CJU 20230114 KE is okay !
# PUS CJU 20230114 OZ is okay !
# PUS CJU 20230114 7C is okay !
# PUS CJU 20230114 LJ is okay !
# [F1] PUS CJU 20230114 TW  - Available ticket is none
# PUS CJU 20230114 BX is okay !
# PUS CJU 20230115 KE is okay !
# PUS CJU 20230115 OZ is okay !
# PUS CJU 20230115 7C is okay !
# PUS CJU 20230115 LJ is okay !
# [F1] PUS CJU 20230115 TW  - Available ticket is none
# PUS CJU 20230115 BX is okay !
# PUS CJU 20230116 KE is okay !
# PUS CJU 20230116 OZ is okay !
# PUS CJU 20230116 7C is okay !
# PUS CJU 20230116 LJ is okay !
# [F1] PUS CJU 20230116 TW  - Available ticket is none
# PUS CJU 20230116 BX is okay !
# PUS CJU 20230117 KE is okay !
# PUS CJU 20230117 OZ is okay !
# PUS CJU 20230117 7C is okay !
# PUS CJU 20230117 LJ is okay !
# [F1] PUS CJU 20230117 TW  - Available ticket is none
# PUS CJU 20230117 BX is okay !
# PUS CJU 20230118 KE is okay !
# PUS CJU 20230118 OZ is okay !
# PUS CJU 20230118 7C is okay !
# PUS CJU 20230118 LJ is okay !
# [F1] PUS CJU 20230118 TW  - Available ticket is none
# PUS CJU 20230118 BX is okay !
# PUS CJU 20230119 KE is okay !
# PUS CJU 20230119 OZ is okay !
# PUS CJU 20230119 7C is okay !
# PUS CJU 20230119 LJ is okay !
# [F1] PUS CJU 20230119 TW  - Available ticket is none
# PUS CJU 20230119 BX is okay !
# PUS CJU 20230120 KE is okay !
# PUS CJU 20230120 OZ is okay !
# PUS CJU 20230120 7C is okay !
# PUS CJU 20230120 LJ is okay !
# [F1] PUS CJU 20230120 TW  - Available ticket is none
# PUS CJU 20230120 BX is okay !
# [F1] PUS CJU 20230121 KE  - Available ticket is none
# [F1] PUS CJU 20230121 OZ  - Available ticket is none
# [F1] PUS CJU 20230121 7C  - Available ticket is none
# PUS CJU 20230121 LJ is okay !
# [F2] Error code: object of type 'NoneType' has no len()
# [F1] PUS CJU 20230121 TW  - Available ticket is none
# PUS CJU 20230121 BX is okay !
# PUS CJU 20230122 KE is okay !
# [F1] PUS CJU 20230122 OZ  - Available ticket is none
# PUS CJU 20230122 7C is okay !
# PUS CJU 20230122 LJ is okay !
# [F1] PUS CJU 20230122 TW  - Available ticket is none
# PUS CJU 20230122 BX is okay !
# PUS CJU 20230123 KE is okay !
# PUS CJU 20230123 OZ is okay !
# PUS CJU 20230123 7C is okay !
# PUS CJU 20230123 LJ is okay !
# [F1] PUS CJU 20230123 TW  - Available ticket is none
# PUS CJU 20230123 BX is okay !
# PUS CJU 20230124 KE is okay !
# PUS CJU 20230124 OZ is okay !
# PUS CJU 20230124 7C is okay !
# PUS CJU 20230124 LJ is okay !
# [F1] PUS CJU 20230124 TW  - Available ticket is none
# PUS CJU 20230124 BX is okay !
# PUS CJU 20230125 KE is okay !
# PUS CJU 20230125 OZ is okay !
# PUS CJU 20230125 7C is okay !
# PUS CJU 20230125 LJ is okay !
# [F1] PUS CJU 20230125 TW  - Available ticket is none
# PUS CJU 20230125 BX is okay !
# PUS CJU 20230126 KE is okay !
# PUS CJU 20230126 OZ is okay !
# PUS CJU 20230126 7C is okay !
# PUS CJU 20230126 LJ is okay !
# [F1] PUS CJU 20230126 TW  - Available ticket is none
# PUS CJU 20230126 BX is okay !
# PUS CJU 20230127 KE is okay !
# PUS CJU 20230127 OZ is okay !
# PUS CJU 20230127 7C is okay !
# PUS CJU 20230127 LJ is okay !
# [F1] PUS CJU 20230127 TW  - Available ticket is none
# PUS CJU 20230127 BX is okay !
# PUS CJU 20230128 KE is okay !
# PUS CJU 20230128 OZ is okay !
# PUS CJU 20230128 7C is okay !
# PUS CJU 20230128 LJ is okay !
# [F1] PUS CJU 20230128 TW  - Available ticket is none
# PUS CJU 20230128 BX is okay !
# PUS CJU 20230129 KE is okay !
# PUS CJU 20230129 OZ is okay !
# PUS CJU 20230129 7C is okay !
# PUS CJU 20230129 LJ is okay !
# [F1] PUS CJU 20230129 TW  - Available ticket is none
# PUS CJU 20230129 BX is okay !
# PUS CJU 20230130 KE is okay !
# [F1] PUS CJU 20230130 OZ  - Available ticket is none
# PUS CJU 20230130 7C is okay !
# PUS CJU 20230130 LJ is okay !
# [F1] PUS CJU 20230130 TW  - Available ticket is none
# PUS CJU 20230130 BX is okay !
# PUS CJU 20230131 KE is okay !
# [F1] PUS CJU 20230131 OZ  - Available ticket is none
# PUS CJU 20230131 7C is okay !
# PUS CJU 20230131 LJ is okay !
# [F1] PUS CJU 20230131 TW  - Available ticket is none
# PUS CJU 20230131 BX is okay !
# PUS CJU 20230201 KE is okay !
# PUS CJU 20230201 OZ is okay !
# PUS CJU 20230201 7C is okay !
# PUS CJU 20230201 LJ is okay !
# [F1] PUS CJU 20230201 TW  - Available ticket is none
# PUS CJU 20230201 BX is okay !
# PUS CJU 20230202 KE is okay !
# PUS CJU 20230202 OZ is okay !
# PUS CJU 20230202 7C is okay !
# PUS CJU 20230202 LJ is okay !
# [F1] PUS CJU 20230202 TW  - Available ticket is none
# PUS CJU 20230202 BX is okay !
# PUS CJU 20230203 KE is okay !
# PUS CJU 20230203 OZ is okay !
# PUS CJU 20230203 7C is okay !
# PUS CJU 20230203 LJ is okay !
# [F1] PUS CJU 20230203 TW  - Available ticket is none
# PUS CJU 20230203 BX is okay !
# PUS CJU 20230204 KE is okay !
# PUS CJU 20230204 OZ is okay !
# PUS CJU 20230204 7C is okay !
# PUS CJU 20230204 LJ is okay !
# [F1] PUS CJU 20230204 TW  - Available ticket is none
# PUS CJU 20230204 BX is okay !
# PUS CJU 20230205 KE is okay !
# PUS CJU 20230205 OZ is okay !
# PUS CJU 20230205 7C is okay !
# PUS CJU 20230205 LJ is okay !
# [F1] PUS CJU 20230205 TW  - Available ticket is none
# PUS CJU 20230205 BX is okay !
# PUS CJU 20230206 KE is okay !
# PUS CJU 20230206 OZ is okay !
# PUS CJU 20230206 7C is okay !
# PUS CJU 20230206 LJ is okay !
# [F1] PUS CJU 20230206 TW  - Available ticket is none
# PUS CJU 20230206 BX is okay !
# PUS CJU 20230207 KE is okay !
# PUS CJU 20230207 OZ is okay !
# PUS CJU 20230207 7C is okay !
# PUS CJU 20230207 LJ is okay !
# [F1] PUS CJU 20230207 TW  - Available ticket is none
# PUS CJU 20230207 BX is okay !
# PUS CJU 20230208 KE is okay !
# [F1] PUS CJU 20230208 OZ  - Available ticket is none
# PUS CJU 20230208 7C is okay !
# PUS CJU 20230208 LJ is okay !
# [F1] PUS CJU 20230208 TW  - Available ticket is none
# PUS CJU 20230208 BX is okay !
# PUS CJU 20230209 KE is okay !
# PUS CJU 20230209 OZ is okay !
# PUS CJU 20230209 7C is okay !
# PUS CJU 20230209 LJ is okay !
# [F1] PUS CJU 20230209 TW  - Available ticket is none
# PUS CJU 20230209 BX is okay !
# PUS CJU 20230210 KE is okay !
# PUS CJU 20230210 OZ is okay !
# PUS CJU 20230210 7C is okay !
# PUS CJU 20230210 LJ is okay !
# [F1] PUS CJU 20230210 TW  - Available ticket is none
# PUS CJU 20230210 BX is okay !
# PUS CJU 20230211 KE is okay !
# PUS CJU 20230211 OZ is okay !
# PUS CJU 20230211 7C is okay !
# PUS CJU 20230211 LJ is okay !
# [F1] PUS CJU 20230211 TW  - Available ticket is none
# PUS CJU 20230211 BX is okay !
# PUS CJU 20230212 KE is okay !
# PUS CJU 20230212 OZ is okay !
# PUS CJU 20230212 7C is okay !
# PUS CJU 20230212 LJ is okay !
# [F1] PUS CJU 20230212 TW  - Available ticket is none
# PUS CJU 20230212 BX is okay !
# PUS CJU 20230213 KE is okay !
# PUS CJU 20230213 OZ is okay !
# PUS CJU 20230213 7C is okay !
# PUS CJU 20230213 LJ is okay !
# [F1] PUS CJU 20230213 TW  - Available ticket is none
# PUS CJU 20230213 BX is okay !
# PUS CJU 20230214 KE is okay !
# PUS CJU 20230214 OZ is okay !
# PUS CJU 20230214 7C is okay !
# PUS CJU 20230214 LJ is okay !
# [F1] PUS CJU 20230214 TW  - Available ticket is none
# PUS CJU 20230214 BX is okay !
# PUS CJU 20230215 KE is okay !
# PUS CJU 20230215 OZ is okay !
# PUS CJU 20230215 7C is okay !
# PUS CJU 20230215 LJ is okay !
# [F1] PUS CJU 20230215 TW  - Available ticket is none
# PUS CJU 20230215 BX is okay !
# PUS CJU 20230216 KE is okay !
# PUS CJU 20230216 OZ is okay !
# PUS CJU 20230216 7C is okay !
# PUS CJU 20230216 LJ is okay !
# [F1] PUS CJU 20230216 TW  - Available ticket is none
# PUS CJU 20230216 BX is okay !
# PUS CJU 20230217 KE is okay !
# PUS CJU 20230217 OZ is okay !
# PUS CJU 20230217 7C is okay !
# PUS CJU 20230217 LJ is okay !
# [F1] PUS CJU 20230217 TW  - Available ticket is none
# PUS CJU 20230217 BX is okay !
# PUS CJU 20230218 KE is okay !
# [F1] PUS CJU 20230218 OZ  - Available ticket is none
# PUS CJU 20230218 7C is okay !
# PUS CJU 20230218 LJ is okay !
# [F1] PUS CJU 20230218 TW  - Available ticket is none
# PUS CJU 20230218 BX is okay !
# PUS CJU 20230219 KE is okay !
# PUS CJU 20230219 OZ is okay !
# PUS CJU 20230219 7C is okay !
# PUS CJU 20230219 LJ is okay !
# [F1] PUS CJU 20230219 TW  - Available ticket is none
# PUS CJU 20230219 BX is okay !
# PUS CJU 20230220 KE is okay !
# PUS CJU 20230220 OZ is okay !
# PUS CJU 20230220 7C is okay !
# PUS CJU 20230220 LJ is okay !
# [F1] PUS CJU 20230220 TW  - Available ticket is none
# PUS CJU 20230220 BX is okay !
# PUS CJU 20230221 KE is okay !
# PUS CJU 20230221 OZ is okay !
# PUS CJU 20230221 7C is okay !
# PUS CJU 20230221 LJ is okay !
# [F1] PUS CJU 20230221 TW  - Available ticket is none
# PUS CJU 20230221 BX is okay !
# PUS CJU 20230222 KE is okay !
# PUS CJU 20230222 OZ is okay !
# PUS CJU 20230222 7C is okay !
# PUS CJU 20230222 LJ is okay !
# [F1] PUS CJU 20230222 TW  - Available ticket is none
# PUS CJU 20230222 BX is okay !
# PUS CJU 20230223 KE is okay !
# PUS CJU 20230223 OZ is okay !
# PUS CJU 20230223 7C is okay !
# PUS CJU 20230223 LJ is okay !
# [F1] PUS CJU 20230223 TW  - Available ticket is none
# PUS CJU 20230223 BX is okay !
# PUS CJU 20230224 KE is okay !
# PUS CJU 20230224 OZ is okay !
# PUS CJU 20230224 7C is okay !
# PUS CJU 20230224 LJ is okay !
# [F1] PUS CJU 20230224 TW  - Available ticket is none
# PUS CJU 20230224 BX is okay !
# PUS CJU 20230225 KE is okay !
# PUS CJU 20230225 OZ is okay !
# PUS CJU 20230225 7C is okay !
# PUS CJU 20230225 LJ is okay !
# [F1] PUS CJU 20230225 TW  - Available ticket is none
# PUS CJU 20230225 BX is okay !
# PUS CJU 20230226 KE is okay !
# PUS CJU 20230226 OZ is okay !
# PUS CJU 20230226 7C is okay !
# PUS CJU 20230226 LJ is okay !
# [F1] PUS CJU 20230226 TW  - Available ticket is none
# PUS CJU 20230226 BX is okay !
# PUS CJU 20230227 KE is okay !
# PUS CJU 20230227 OZ is okay !
# PUS CJU 20230227 7C is okay !
# PUS CJU 20230227 LJ is okay !
# [F1] PUS CJU 20230227 TW  - Available ticket is none
# PUS CJU 20230227 BX is okay !
# PUS CJU 20230228 KE is okay !
# PUS CJU 20230228 OZ is okay !
# PUS CJU 20230228 7C is okay !
# PUS CJU 20230228 LJ is okay !
# [F1] PUS CJU 20230228 TW  - Available ticket is none
# PUS CJU 20230228 BX is okay !
# PUS CJU 20230301 KE is okay !
# [F1] PUS CJU 20230301 OZ  - Available ticket is none
# PUS CJU 20230301 7C is okay !
# PUS CJU 20230301 LJ is okay !
# [F1] PUS CJU 20230301 TW  - Available ticket is none
# PUS CJU 20230301 BX is okay !
# PUS CJU 20230302 KE is okay !
# [F1] PUS CJU 20230302 OZ  - Available ticket is none
# PUS CJU 20230302 7C is okay !
# PUS CJU 20230302 LJ is okay !
# [F1] PUS CJU 20230302 TW  - Available ticket is none
# PUS CJU 20230302 BX is okay !
# PUS CJU 20230303 KE is okay !
# [F1] PUS CJU 20230303 OZ  - Available ticket is none
# PUS CJU 20230303 7C is okay !
# PUS CJU 20230303 LJ is okay !
# [F1] PUS CJU 20230303 TW  - Available ticket is none
#  20%|██        | 2/10 [08:25<34:38, 259.77s/it]
# PUS CJU 20230303 BX is okay !
# CJJ CJU 20230103 KE is okay !
# CJJ CJU 20230103 OZ is okay !
# CJJ CJU 20230103 7C is okay !
# CJJ CJU 20230103 LJ is okay !
# CJJ CJU 20230103 TW is okay !
# [F1] CJJ CJU 20230103 BX  - Available ticket is none
# CJJ CJU 20230104 KE is okay !
# CJJ CJU 20230104 OZ is okay !
# CJJ CJU 20230104 7C is okay !
# CJJ CJU 20230104 LJ is okay !
# CJJ CJU 20230104 TW is okay !
# [F1] TAE CJU 20230115 BX  - Available ticket is none
# TAE CJU 20230116 KE is okay !
# TAE CJU 20230116 OZ is okay !
# TAE CJU 20230116 7C is okay !
# TAE CJU 20230116 LJ is okay !
# TAE CJU 20230116 TW is okay !
# [F1] TAE CJU 20230116 BX  - Available ticket is none
# TAE CJU 20230117 KE is okay !
# TAE CJU 20230117 OZ is okay !
# TAE CJU 20230117 7C is okay !
# TAE CJU 20230117 LJ is okay !
# TAE CJU 20230117 TW is okay !
# [F1] TAE CJU 20230117 BX  - Available ticket is none
# TAE CJU 20230118 KE is okay !
# TAE CJU 20230118 OZ is okay !
# TAE CJU 20230118 7C is okay !
# TAE CJU 20230118 LJ is okay !
# TAE CJU 20230118 TW is okay !
# [F1] TAE CJU 20230118 BX  - Available ticket is none
# TAE CJU 20230119 KE is okay !
# TAE CJU 20230119 OZ is okay !
# TAE CJU 20230119 7C is okay !
# TAE CJU 20230119 LJ is okay !
# TAE CJU 20230119 TW is okay !
# [F1] TAE CJU 20230119 BX  - Available ticket is none
# TAE CJU 20230120 KE is okay !
# TAE CJU 20230120 OZ is okay !
# TAE CJU 20230120 7C is okay !
# TAE CJU 20230120 LJ is okay !
# TAE CJU 20230120 TW is okay !
# [F1] TAE CJU 20230120 BX  - Available ticket is none
# [F1] TAE CJU 20230121 KE  - Available ticket is none
# TAE CJU 20230121 OZ is okay !
# TAE CJU 20230121 7C is okay !
# TAE CJU 20230121 LJ is okay !
# TAE CJU 20230121 TW is okay !
# [F1] TAE CJU 20230121 BX  - Available ticket is none
# TAE CJU 20230122 KE is okay !
# TAE CJU 20230122 OZ is okay !
# TAE CJU 20230122 7C is okay !
# TAE CJU 20230122 LJ is okay !
# TAE CJU 20230122 TW is okay !
# [F1] TAE CJU 20230122 BX  - Available ticket is none
# TAE CJU 20230123 KE is okay !
# TAE CJU 20230123 OZ is okay !
# TAE CJU 20230123 7C is okay !
# TAE CJU 20230123 LJ is okay !
# TAE CJU 20230123 TW is okay !
# [F1] TAE CJU 20230123 BX  - Available ticket is none
# TAE CJU 20230124 KE is okay !
# TAE CJU 20230124 OZ is okay !
# TAE CJU 20230124 7C is okay !
# TAE CJU 20230124 LJ is okay !
# TAE CJU 20230124 TW is okay !
# [F1] TAE CJU 20230124 BX  - Available ticket is none
# TAE CJU 20230125 KE is okay !
# TAE CJU 20230125 OZ is okay !
# TAE CJU 20230125 7C is okay !
# TAE CJU 20230125 LJ is okay !
# TAE CJU 20230125 TW is okay !
# [F1] TAE CJU 20230125 BX  - Available ticket is none
# TAE CJU 20230126 KE is okay !
# TAE CJU 20230126 OZ is okay !
# TAE CJU 20230126 7C is okay !
# TAE CJU 20230126 LJ is okay !
# TAE CJU 20230126 TW is okay !
# [F1] TAE CJU 20230126 BX  - Available ticket is none
# TAE CJU 20230127 KE is okay !
# TAE CJU 20230127 OZ is okay !
# TAE CJU 20230127 7C is okay !
# TAE CJU 20230127 LJ is okay !
# TAE CJU 20230127 TW is okay !
# [F1] TAE CJU 20230127 BX  - Available ticket is none
# TAE CJU 20230128 KE is okay !
# TAE CJU 20230128 OZ is okay !
# TAE CJU 20230128 7C is okay !
# TAE CJU 20230128 LJ is okay !
# TAE CJU 20230128 TW is okay !
# [F1] TAE CJU 20230128 BX  - Available ticket is none
# TAE CJU 20230129 KE is okay !
# TAE CJU 20230129 OZ is okay !
# TAE CJU 20230129 7C is okay !
# TAE CJU 20230129 LJ is okay !
# TAE CJU 20230129 TW is okay !
# [F1] TAE CJU 20230129 BX  - Available ticket is none
# TAE CJU 20230130 KE is okay !
# [F1] TAE CJU 20230130 OZ  - Available ticket is none
# TAE CJU 20230130 7C is okay !
# TAE CJU 20230130 LJ is okay !
# TAE CJU 20230130 TW is okay !
# [F1] TAE CJU 20230130 BX  - Available ticket is none
# TAE CJU 20230131 KE is okay !
# TAE CJU 20230131 OZ is okay !
# TAE CJU 20230131 7C is okay !
# TAE CJU 20230131 LJ is okay !
# TAE CJU 20230131 TW is okay !
# [F1] TAE CJU 20230131 BX  - Available ticket is none
# TAE CJU 20230201 KE is okay !
# TAE CJU 20230201 OZ is okay !
# TAE CJU 20230201 7C is okay !
# TAE CJU 20230201 LJ is okay !
# TAE CJU 20230201 TW is okay !
# [F1] TAE CJU 20230201 BX  - Available ticket is none
# TAE CJU 20230202 KE is okay !
# TAE CJU 20230202 OZ is okay !
# TAE CJU 20230202 7C is okay !
# TAE CJU 20230202 LJ is okay !
# TAE CJU 20230202 TW is okay !
# [F1] TAE CJU 20230202 BX  - Available ticket is none
# TAE CJU 20230203 KE is okay !
# TAE CJU 20230203 OZ is okay !
# TAE CJU 20230203 7C is okay !
# TAE CJU 20230203 LJ is okay !
# TAE CJU 20230203 TW is okay !
# [F1] TAE CJU 20230203 BX  - Available ticket is none
# TAE CJU 20230204 KE is okay !
# TAE CJU 20230204 OZ is okay !
# TAE CJU 20230204 7C is okay !
# TAE CJU 20230204 LJ is okay !
# TAE CJU 20230204 TW is okay !
# [F1] TAE CJU 20230204 BX  - Available ticket is none
# TAE CJU 20230205 KE is okay !
# TAE CJU 20230205 OZ is okay !
# TAE CJU 20230205 7C is okay !
# TAE CJU 20230205 LJ is okay !
# TAE CJU 20230205 TW is okay !
# [F1] TAE CJU 20230205 BX  - Available ticket is none
# TAE CJU 20230206 KE is okay !
# TAE CJU 20230206 OZ is okay !
# TAE CJU 20230206 7C is okay !
# TAE CJU 20230206 LJ is okay !
# TAE CJU 20230206 TW is okay !
# [F1] TAE CJU 20230206 BX  - Available ticket is none
# TAE CJU 20230207 KE is okay !
# TAE CJU 20230207 OZ is okay !
# TAE CJU 20230207 7C is okay !
# TAE CJU 20230207 LJ is okay !
# TAE CJU 20230207 TW is okay !
# [F1] TAE CJU 20230207 BX  - Available ticket is none
# TAE CJU 20230208 KE is okay !
# TAE CJU 20230208 OZ is okay !
# TAE CJU 20230208 7C is okay !
# TAE CJU 20230208 LJ is okay !
# TAE CJU 20230208 TW is okay !
# [F1] TAE CJU 20230208 BX  - Available ticket is none
# TAE CJU 20230209 KE is okay !
# TAE CJU 20230209 OZ is okay !
# TAE CJU 20230209 7C is okay !
# TAE CJU 20230209 LJ is okay !
# TAE CJU 20230209 TW is okay !
# [F1] TAE CJU 20230209 BX  - Available ticket is none
# [F1] TAE CJU 20230210 KE  - Available ticket is none
# TAE CJU 20230210 OZ is okay !
# TAE CJU 20230210 7C is okay !
# TAE CJU 20230210 LJ is okay !
# TAE CJU 20230210 TW is okay !
# [F1] TAE CJU 20230210 BX  - Available ticket is none
# TAE CJU 20230211 KE is okay !
# TAE CJU 20230211 OZ is okay !
# TAE CJU 20230211 7C is okay !
# TAE CJU 20230211 LJ is okay !
# TAE CJU 20230211 TW is okay !
# [F1] TAE CJU 20230211 BX  - Available ticket is none
# TAE CJU 20230212 KE is okay !
# TAE CJU 20230212 OZ is okay !
# TAE CJU 20230212 7C is okay !
# TAE CJU 20230212 LJ is okay !
# TAE CJU 20230212 TW is okay !
# [F1] TAE CJU 20230212 BX  - Available ticket is none
# TAE CJU 20230213 KE is okay !
# TAE CJU 20230213 OZ is okay !
# TAE CJU 20230213 7C is okay !
# TAE CJU 20230213 LJ is okay !
# TAE CJU 20230213 TW is okay !
# [F1] TAE CJU 20230213 BX  - Available ticket is none
# TAE CJU 20230214 KE is okay !
# TAE CJU 20230214 OZ is okay !
# TAE CJU 20230214 7C is okay !
# TAE CJU 20230214 LJ is okay !
# TAE CJU 20230214 TW is okay !
# [F1] TAE CJU 20230214 BX  - Available ticket is none
# TAE CJU 20230215 KE is okay !
# TAE CJU 20230215 OZ is okay !
# TAE CJU 20230215 7C is okay !
# TAE CJU 20230215 LJ is okay !
# TAE CJU 20230215 TW is okay !
# [F1] TAE CJU 20230215 BX  - Available ticket is none
# TAE CJU 20230216 KE is okay !
# TAE CJU 20230216 OZ is okay !
# TAE CJU 20230216 7C is okay !
# TAE CJU 20230216 LJ is okay !
# TAE CJU 20230216 TW is okay !
# [F1] TAE CJU 20230216 BX  - Available ticket is none
# [F1] TAE CJU 20230217 KE  - Available ticket is none
# TAE CJU 20230217 OZ is okay !
# TAE CJU 20230217 7C is okay !
# TAE CJU 20230217 LJ is okay !
# TAE CJU 20230217 TW is okay !
# [F1] TAE CJU 20230217 BX  - Available ticket is none
# TAE CJU 20230218 KE is okay !
# TAE CJU 20230218 OZ is okay !
# TAE CJU 20230218 7C is okay !
# TAE CJU 20230218 LJ is okay !
# TAE CJU 20230218 TW is okay !
# [F1] TAE CJU 20230218 BX  - Available ticket is none
# TAE CJU 20230219 KE is okay !
# [F1] TAE CJU 20230219 OZ  - Available ticket is none
# TAE CJU 20230219 7C is okay !
# TAE CJU 20230219 LJ is okay !
# TAE CJU 20230219 TW is okay !
# [F1] TAE CJU 20230219 BX  - Available ticket is none
# TAE CJU 20230220 KE is okay !
# TAE CJU 20230220 OZ is okay !
# TAE CJU 20230220 7C is okay !
# TAE CJU 20230220 LJ is okay !
# TAE CJU 20230220 TW is okay !
# [F1] TAE CJU 20230220 BX  - Available ticket is none
# TAE CJU 20230221 KE is okay !
# TAE CJU 20230221 OZ is okay !
# TAE CJU 20230221 7C is okay !
# TAE CJU 20230221 LJ is okay !
# TAE CJU 20230221 TW is okay !
# [F1] TAE CJU 20230221 BX  - Available ticket is none
# TAE CJU 20230222 KE is okay !
# TAE CJU 20230222 OZ is okay !
# TAE CJU 20230222 7C is okay !
# TAE CJU 20230222 LJ is okay !
# TAE CJU 20230222 TW is okay !
# [F1] TAE CJU 20230222 BX  - Available ticket is none
# TAE CJU 20230223 KE is okay !
# TAE CJU 20230223 OZ is okay !
# TAE CJU 20230223 7C is okay !
# TAE CJU 20230223 LJ is okay !
# TAE CJU 20230223 TW is okay !
# [F1] TAE CJU 20230223 BX  - Available ticket is none
# TAE CJU 20230224 KE is okay !
# TAE CJU 20230224 OZ is okay !
# TAE CJU 20230224 7C is okay !
# TAE CJU 20230224 LJ is okay !
# TAE CJU 20230224 TW is okay !
# [F1] TAE CJU 20230224 BX  - Available ticket is none
# TAE CJU 20230225 KE is okay !
# TAE CJU 20230225 OZ is okay !
# TAE CJU 20230225 7C is okay !
# TAE CJU 20230225 LJ is okay !
# TAE CJU 20230225 TW is okay !
# [F1] TAE CJU 20230225 BX  - Available ticket is none
# TAE CJU 20230226 KE is okay !
# TAE CJU 20230226 OZ is okay !
# TAE CJU 20230226 7C is okay !
# TAE CJU 20230226 LJ is okay !
# TAE CJU 20230226 TW is okay !
# [F1] TAE CJU 20230226 BX  - Available ticket is none
# TAE CJU 20230227 KE is okay !
# TAE CJU 20230227 OZ is okay !
# TAE CJU 20230227 7C is okay !
# TAE CJU 20230227 LJ is okay !
# TAE CJU 20230227 TW is okay !
# [F1] TAE CJU 20230227 BX  - Available ticket is none
# TAE CJU 20230228 KE is okay !
# TAE CJU 20230228 OZ is okay !
# TAE CJU 20230228 7C is okay !
# TAE CJU 20230228 LJ is okay !
# ...
# CJU PUS 20230219 OZ is okay !
# CJU PUS 20230219 7C is okay !
# CJU PUS 20230219 LJ is okay !
# [F1] CJU PUS 20230219 TW  - Available ticket is none
# CJU PUS 20230219 BX is okay !
# CJU PUS 20230220 KE is okay !
# CJU PUS 20230220 OZ is okay !
# CJU PUS 20230220 7C is okay !
# CJU PUS 20230220 LJ is okay !
# [F1] CJU PUS 20230220 TW  - Available ticket is none
# CJU PUS 20230220 BX is okay !
# CJU PUS 20230221 KE is okay !
# CJU PUS 20230221 OZ is okay !
# CJU PUS 20230221 7C is okay !
# CJU PUS 20230221 LJ is okay !
# [F1] CJU PUS 20230221 TW  - Available ticket is none
# CJU PUS 20230221 BX is okay !
# CJU PUS 20230222 KE is okay !
# CJU PUS 20230222 OZ is okay !
# CJU PUS 20230222 7C is okay !
# CJU PUS 20230222 LJ is okay !
# [F1] CJU PUS 20230222 TW  - Available ticket is none
# CJU PUS 20230222 BX is okay !
# CJU PUS 20230223 KE is okay !
# CJU PUS 20230223 OZ is okay !
# CJU PUS 20230223 7C is okay !
# CJU PUS 20230223 LJ is okay !
# [F1] CJU PUS 20230223 TW  - Available ticket is none
# CJU PUS 20230223 BX is okay !
# CJU PUS 20230224 KE is okay !
# CJU PUS 20230224 OZ is okay !
# CJU PUS 20230224 7C is okay !
# CJU PUS 20230224 LJ is okay !
# [F1] CJU PUS 20230224 TW  - Available ticket is none
# CJU PUS 20230224 BX is okay !
# CJU PUS 20230225 KE is okay !
# CJU PUS 20230225 OZ is okay !
# CJU PUS 20230225 7C is okay !
# CJU PUS 20230225 LJ is okay !
# [F1] CJU PUS 20230225 TW  - Available ticket is none
# CJU PUS 20230225 BX is okay !
# CJU PUS 20230226 KE is okay !
# CJU PUS 20230226 OZ is okay !
# CJU PUS 20230226 7C is okay !
# CJU PUS 20230226 LJ is okay !
# [F1] CJU PUS 20230226 TW  - Available ticket is none
# CJU PUS 20230226 BX is okay !
# CJU PUS 20230227 KE is okay !
# CJU PUS 20230227 OZ is okay !
# CJU PUS 20230227 7C is okay !
# CJU PUS 20230227 LJ is okay !
# [F1] CJU PUS 20230227 TW  - Available ticket is none
# CJU PUS 20230227 BX is okay !
# CJU PUS 20230228 KE is okay !
# CJU PUS 20230228 OZ is okay !
# CJU PUS 20230228 7C is okay !
# CJU PUS 20230228 LJ is okay !
# [F1] CJU PUS 20230228 TW  - Available ticket is none
# CJU PUS 20230228 BX is okay !
# CJU PUS 20230301 KE is okay !
# [F1] CJU PUS 20230301 OZ  - Available ticket is none
# CJU PUS 20230301 7C is okay !
# CJU PUS 20230301 LJ is okay !
# [F1] CJU PUS 20230301 TW  - Available ticket is none
# CJU PUS 20230301 BX is okay !
# CJU PUS 20230302 KE is okay !
# [F1] CJU PUS 20230302 OZ  - Available ticket is none
# CJU PUS 20230302 7C is okay !
# CJU PUS 20230302 LJ is okay !
# [F1] CJU PUS 20230302 TW  - Available ticket is none
# CJU PUS 20230302 BX is okay !
# CJU PUS 20230303 KE is okay !
# [F1] CJU PUS 20230303 OZ  - Available ticket is none
# CJU PUS 20230303 7C is okay !
# CJU PUS 20230303 LJ is okay !
# [F1] CJU PUS 20230303 TW  - Available ticket is none
#  70%|███████   | 7/10 [32:37<14:06, 282.29s/it]
# CJU PUS 20230303 BX is okay !
# CJU CJJ 20230103 KE is okay !
# CJU CJJ 20230103 OZ is okay !
# CJU CJJ 20230103 7C is okay !
# CJU CJJ 20230103 LJ is okay !
# CJU CJJ 20230103 TW is okay !
# [F1] CJU CJJ 20230103 BX  - Available ticket is none
# CJU CJJ 20230104 KE is okay !
# CJU CJJ 20230104 OZ is okay !
# CJU CJJ 20230104 7C is okay !
# CJU CJJ 20230104 LJ is okay !
# CJU CJJ 20230104 TW is okay !
# [F1] CJU CJJ 20230104 BX  - Available ticket is none
# CJU CJJ 20230105 KE is okay !
# CJU CJJ 20230105 OZ is okay !
# CJU CJJ 20230105 7C is okay !
# CJU CJJ 20230105 LJ is okay !
# CJU CJJ 20230105 TW is okay !
# [F1] CJU CJJ 20230105 BX  - Available ticket is none
# CJU CJJ 20230106 KE is okay !
# CJU CJJ 20230106 OZ is okay !
# CJU CJJ 20230106 7C is okay !
# CJU CJJ 20230106 LJ is okay !
# CJU CJJ 20230106 TW is okay !
# [F1] CJU CJJ 20230106 BX  - Available ticket is none
# CJU CJJ 20230107 KE is okay !
# CJU CJJ 20230107 OZ is okay !
# CJU CJJ 20230107 7C is okay !
# CJU CJJ 20230119 LJ is okay !
# CJU CJJ 20230119 TW is okay !
# [F1] CJU CJJ 20230119 BX  - Available ticket is none
# CJU CJJ 20230120 KE is okay !
# CJU CJJ 20230120 OZ is okay !
# CJU CJJ 20230120 7C is okay !
# CJU CJJ 20230120 LJ is okay !
# CJU CJJ 20230120 TW is okay !
# [F1] CJU CJJ 20230120 BX  - Available ticket is none
# CJU CJJ 20230121 KE is okay !
# CJU CJJ 20230121 OZ is okay !
# CJU CJJ 20230121 7C is okay !
# CJU CJJ 20230121 LJ is okay !
# CJU CJJ 20230121 TW is okay !
# [F1] CJU CJJ 20230121 BX  - Available ticket is none
# CJU CJJ 20230122 KE is okay !
# CJU CJJ 20230122 OZ is okay !
# CJU CJJ 20230122 7C is okay !
# CJU CJJ 20230122 LJ is okay !
# CJU CJJ 20230122 TW is okay !
# [F1] CJU CJJ 20230122 BX  - Available ticket is none
# CJU CJJ 20230123 KE is okay !
# CJU CJJ 20230123 OZ is okay !
# [F1] CJU CJJ 20230123 7C  - Available ticket is none
# CJU CJJ 20230123 LJ is okay !
# [F2] Error code: object of type 'NoneType' has no len()
# CJU CJJ 20230123 TW is okay !
# [F2] Error code: object of type 'NoneType' has no len()
# [F1] CJU CJJ 20230123 BX  - Available ticket is none
# [F1] CJU CJJ 20230124 KE  - Available ticket is none
# [F1] CJU CJJ 20230124 OZ  - Available ticket is none
# CJU CJJ 20230124 7C is okay !
# CJU CJJ 20230124 LJ is okay !
# [F2] Error code: object of type 'NoneType' has no len()
# CJU CJJ 20230124 TW is okay !
# [F2] Error code: object of type 'NoneType' has no len()
# [F1] CJU CJJ 20230124 BX  - Available ticket is none
# CJU CJJ 20230125 KE is okay !
# CJU CJJ 20230125 OZ is okay !
# CJU CJJ 20230125 7C is okay !
# CJU CJJ 20230125 LJ is okay !
# CJU CJJ 20230125 TW is okay !
# [F1] CJU CJJ 20230125 BX  - Available ticket is none
# CJU CJJ 20230126 KE is okay !
# CJU CJJ 20230126 OZ is okay !
# CJU CJJ 20230126 7C is okay !
# CJU CJJ 20230126 LJ is okay !
# CJU CJJ 20230126 TW is okay !
# [F1] CJU CJJ 20230126 BX  - Available ticket is none
# CJU CJJ 20230127 KE is okay !
# CJU CJJ 20230127 OZ is okay !
# CJU CJJ 20230127 7C is okay !
# CJU CJJ 20230127 LJ is okay !
# CJU CJJ 20230127 TW is okay !
# [F1] CJU CJJ 20230127 BX  - Available ticket is none
# CJU CJJ 20230128 KE is okay !
# CJU CJJ 20230128 OZ is okay !
# CJU CJJ 20230128 7C is okay !
# CJU CJJ 20230128 LJ is okay !
# CJU CJJ 20230128 TW is okay !
# [F1] CJU CJJ 20230128 BX  - Available ticket is none
# CJU CJJ 20230129 KE is okay !
# CJU CJJ 20230129 OZ is okay !
# CJU CJJ 20230129 7C is okay !
# CJU CJJ 20230129 LJ is okay !
# CJU CJJ 20230129 TW is okay !
# [F1] CJU CJJ 20230129 BX  - Available ticket is none
# CJU CJJ 20230130 KE is okay !
# CJU CJJ 20230130 OZ is okay !
# CJU CJJ 20230130 7C is okay !
# CJU CJJ 20230130 LJ is okay !
# CJU CJJ 20230130 TW is okay !
# [F1] CJU CJJ 20230130 BX  - Available ticket is none
# CJU CJJ 20230131 KE is okay !
# CJU CJJ 20230131 OZ is okay !
# CJU CJJ 20230131 7C is okay !
# CJU CJJ 20230131 LJ is okay !
# CJU CJJ 20230131 TW is okay !
# [F1] CJU CJJ 20230131 BX  - Available ticket is none
# CJU CJJ 20230201 KE is okay !
# CJU CJJ 20230201 OZ is okay !
# CJU CJJ 20230201 7C is okay !
# CJU CJJ 20230201 LJ is okay !
# CJU CJJ 20230201 TW is okay !
# [F1] CJU CJJ 20230201 BX  - Available ticket is none
# CJU CJJ 20230202 KE is okay !
# CJU CJJ 20230202 OZ is okay !
# CJU CJJ 20230202 7C is okay !
# CJU CJJ 20230202 LJ is okay !
# CJU CJJ 20230202 TW is okay !
# [F1] CJU CJJ 20230202 BX  - Available ticket is none
# CJU CJJ 20230203 KE is okay !
# CJU CJJ 20230203 OZ is okay !
# CJU CJJ 20230203 7C is okay !
# CJU CJJ 20230203 LJ is okay !
# CJU CJJ 20230203 TW is okay !
# [F1] CJU CJJ 20230203 BX  - Available ticket is none
# CJU CJJ 20230204 KE is okay !
# CJU CJJ 20230204 OZ is okay !
# CJU CJJ 20230204 7C is okay !
# CJU CJJ 20230204 LJ is okay !
# CJU CJJ 20230204 TW is okay !
# [F1] CJU CJJ 20230204 BX  - Available ticket is none
# CJU CJJ 20230205 KE is okay !
# CJU CJJ 20230205 OZ is okay !
# CJU CJJ 20230205 7C is okay !
# CJU CJJ 20230205 LJ is okay !
# CJU CJJ 20230205 TW is okay !
# [F1] CJU CJJ 20230205 BX  - Available ticket is none
# CJU CJJ 20230206 KE is okay !
# [F1] CJU CJJ 20230206 OZ  - Available ticket is none
# CJU CJJ 20230206 7C is okay !
# CJU CJJ 20230206 LJ is okay !
# CJU CJJ 20230206 TW is okay !
# [F1] CJU CJJ 20230206 BX  - Available ticket is none
# CJU CJJ 20230207 KE is okay !
# CJU CJJ 20230207 OZ is okay !
# CJU CJJ 20230207 7C is okay !
# CJU CJJ 20230207 LJ is okay !
# CJU CJJ 20230207 TW is okay !
# [F1] CJU CJJ 20230207 BX  - Available ticket is none
# CJU CJJ 20230208 KE is okay !
# [F1] CJU CJJ 20230208 OZ  - Available ticket is none
# CJU CJJ 20230208 7C is okay !
# CJU CJJ 20230208 LJ is okay !
# CJU CJJ 20230208 TW is okay !
# [F1] CJU CJJ 20230208 BX  - Available ticket is none
# CJU CJJ 20230209 KE is okay !
# CJU CJJ 20230209 OZ is okay !
# CJU CJJ 20230209 7C is okay !
# CJU CJJ 20230209 LJ is okay !
# CJU CJJ 20230209 TW is okay !
# [F1] CJU CJJ 20230209 BX  - Available ticket is none
# CJU CJJ 20230210 KE is okay !
# CJU CJJ 20230210 OZ is okay !
# CJU CJJ 20230210 7C is okay !
# CJU CJJ 20230210 LJ is okay !
# CJU CJJ 20230210 TW is okay !
# [F1] CJU CJJ 20230210 BX  - Available ticket is none
# CJU CJJ 20230211 KE is okay !
# CJU CJJ 20230211 OZ is okay !
# CJU CJJ 20230211 7C is okay !
# CJU CJJ 20230211 LJ is okay !
# CJU CJJ 20230211 TW is okay !
# CJU CJJ 20230223 TW is okay !
# [F1] CJU CJJ 20230223 BX  - Available ticket is none
# CJU CJJ 20230224 KE is okay !
# CJU CJJ 20230224 OZ is okay !
# CJU CJJ 20230224 7C is okay !
# CJU CJJ 20230224 LJ is okay !
# CJU CJJ 20230224 TW is okay !
# [F1] CJU CJJ 20230224 BX  - Available ticket is none
# CJU CJJ 20230225 KE is okay !
# CJU CJJ 20230225 OZ is okay !
# CJU CJJ 20230225 7C is okay !
# CJU CJJ 20230225 LJ is okay !
# CJU CJJ 20230225 TW is okay !
# [F1] CJU CJJ 20230225 BX  - Available ticket is none
# CJU CJJ 20230226 KE is okay !
# CJU CJJ 20230226 OZ is okay !
# CJU CJJ 20230226 7C is okay !
# CJU CJJ 20230226 LJ is okay !
# CJU CJJ 20230226 TW is okay !
# [F1] CJU CJJ 20230226 BX  - Available ticket is none
# CJU CJJ 20230227 KE is okay !
# CJU CJJ 20230227 OZ is okay !
# CJU CJJ 20230227 7C is okay !
# CJU CJJ 20230227 LJ is okay !
# CJU CJJ 20230227 TW is okay !
# [F1] CJU CJJ 20230227 BX  - Available ticket is none
# CJU CJJ 20230228 KE is okay !
# CJU CJJ 20230228 OZ is okay !
# CJU CJJ 20230228 7C is okay !
# CJU CJJ 20230228 LJ is okay !
# CJU CJJ 20230228 TW is okay !
# [F1] CJU CJJ 20230228 BX  - Available ticket is none
# CJU CJJ 20230301 KE is okay !
# CJU CJJ 20230301 OZ is okay !
# CJU CJJ 20230301 7C is okay !
# CJU CJJ 20230301 LJ is okay !
# CJU CJJ 20230301 TW is okay !
# [F1] CJU CJJ 20230301 BX  - Available ticket is none
# CJU CJJ 20230302 KE is okay !
# CJU CJJ 20230302 OZ is okay !
# CJU CJJ 20230302 7C is okay !
# CJU CJJ 20230302 LJ is okay !
# CJU CJJ 20230302 TW is okay !
# [F1] CJU CJJ 20230302 BX  - Available ticket is none
# CJU CJJ 20230303 KE is okay !
# [F1] CJU CJJ 20230303 OZ  - Available ticket is none
# CJU CJJ 20230303 7C is okay !
# CJU CJJ 20230303 LJ is okay !
# CJU CJJ 20230303 TW is okay !
#  80%|████████  | 8/10 [37:09<09:18, 279.22s/it]
# [F1] CJU CJJ 20230303 BX  - Available ticket is none
# CJU TAE 20230103 KE is okay !
# CJU TAE 20230103 OZ is okay !
# CJU TAE 20230103 7C is okay !
# CJU TAE 20230103 LJ is okay !
# CJU TAE 20230103 TW is okay !
# [F1] CJU TAE 20230103 BX  - Available ticket is none
# CJU TAE 20230104 KE is okay !
# CJU TAE 20230104 OZ is okay !
# CJU TAE 20230104 7C is okay !
# CJU TAE 20230104 LJ is okay !
# CJU TAE 20230104 TW is okay !
# [F1] CJU TAE 20230104 BX  - Available ticket is none
# CJU TAE 20230105 KE is okay !
# CJU TAE 20230105 OZ is okay !
# CJU TAE 20230105 7C is okay !
# CJU TAE 20230105 LJ is okay !
# CJU TAE 20230105 TW is okay !
# [F1] CJU TAE 20230105 BX  - Available ticket is none
# CJU TAE 20230106 KE is okay !
# CJU TAE 20230106 OZ is okay !
